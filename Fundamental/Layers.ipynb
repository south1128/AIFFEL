# %% [markdown]
# ## Layer
# When an object is composed of several logical objects, each of these objects is referred to as a layer
#
# ### Linear Layer
# The Linear Layer convert data into specific dimension using linear transformation

# %%
import tensorflow as tf

batch_size = 64
boxes = tf.zeros((batch_size,4,2))

print('1단계 연산 준비:',boxes.shape)

first_linear = tf.keras.layers.Dense(units=1,use_bias=False)

first_out = first_linear(boxes)
first_out = tf.squeeze(first_out,axis=-1)

print('1단계 연산 결과:',first_out.shape)
print('1단계 Linear layer 의 weight 형태:',first_linear.weights[0].shape)

print('\n단계 연산 준비:',first_out.shape)

second_linear = tf.keras.layers.Dense(units=1,use_bias=False)
second_out = second_linear(first_out)
second_out = tf.squeeze(second_out,axis=-1)

print('2단계 연산 결과:',second_out.shape)
print('2단계 Linear layer 의 weight 형태:',second_linear.weights[0].shape)
# Out:
# 1단계 연산 준비: (64, 4, 2)
# 1단계 연산 결과: (64, 4)
# 1단계 Linear layer 의 weight 형태: (2, 1)
#
# 단계 연산 준비: (64, 4)
# 2단계 연산 결과: (64,)
# 2단계 Linear layer 의 weight 형태: (4, 1)

# %%
import tensorflow as tf

batch_size = 64
boxes = tf.zeros((batch_size, 4, 2))

print("1단계 연산 준비:", boxes.shape)

first_linear = tf.keras.layers.Dense(units=3,use_bias=False)

first_out = first_linear(boxes)

print("1단계 연산 결과:", first_out.shape)
print("1단계 Linear Layer의 Weight 형태:", first_linear.weights[0].shape)

print("\n2단계 연산 준비:", first_out.shape)

second_linear = tf.keras.layers.Dense(units=1, use_bias=False)
second_out = second_linear(first_out)
second_out = tf.squeeze(second_out, axis=-1)

print("2단계 연산 결과:", second_out.shape)
print("2단계 Linear Layer의 Weight 형태:", second_linear.weights[0].shape)

print("\n3단계 연산 준비:", second_out.shape)

third_linear = tf.keras.layers.Dense(units=1, use_bias=False)
third_out = third_linear(second_out)
third_out = tf.squeeze(third_out, axis=-1)

print("3단계 연산 결과:", third_out.shape)
print("3단계 Linear Layer의 Weight 형태:", third_linear.weights[0].shape)

total_params = \
first_linear.count_params() + \
second_linear.count_params() + \
third_linear.count_params()

print("총 Parameters:", total_params)
# Out:
# 1단계 연산 준비: (64, 4, 2)
# 1단계 연산 결과: (64, 4, 3)
# 1단계 Linear Layer의 Weight 형태: (2, 3)
#
# 2단계 연산 준비: (64, 4, 3)
# 2단계 연산 결과: (64, 4)
# 2단계 Linear Layer의 Weight 형태: (3, 1)
#
# 3단계 연산 준비: (64, 4)
# 3단계 연산 결과: (64,)
# 3단계 Linear Layer의 Weight 형태: (4, 1)
# 총 Parameters: 13

# %%
import tensorflow as tf

batch_size = 64
pic = tf.zeros((batch_size, 1920, 1080, 3))

print("입력 이미지 데이터:", pic.shape)
conv_layer = tf.keras.layers.Conv2D(filters=16,kernel_size=(5,5),strides=5,use_bias=False)

conv_out = conv_layer(pic)
print("\nConvolution 결과:", conv_out.shape)
print("Convolution Layer의 Parameter 수:", conv_layer.count_params())

flatten_out = tf.keras.layers.Flatten()(conv_out)
print('\n1차원으로 펼친 데이터:',flatten_out.shape)

linear_layer = tf.keras.layers.Dense(units=1,use_bias=False)
linear_out = linear_layer(flatten_out)

print('\nLinear 결과:',linear_out.shape)
print('Linear layer 의 parameter 수:',linear_layer.count_params())
# Out:
# 입력 이미지 데이터: (64, 1920, 1080, 3)
#
# Convolution 결과: (64, 384, 216, 16)
# Convolution Layer의 Parameter 수: 1200
#
# 1차원으로 펼친 데이터: (64, 1327104)
#
# Linear 결과: (64, 1)
# Linear layer 의 parameter 수: 1327104

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import json
import matplotlib.pyplot as plt 

# Load Mnist data
(x_train, _), (x_test, _) = mnist.load_data()

x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# AutoEncoder 모델 구성 - Input 부분
input_shape = x_train.shape[1:]
input_img = Input(shape=input_shape)

# AutoEncoder 모델 구성 - Encoder 부분
encode_conv_layer_1 = Conv2D(16, (3, 3), activation='relu', padding='same')
encode_pool_layer_1 = MaxPooling2D((2, 2), padding='same')
encode_conv_layer_2 = Conv2D(8, (3, 3), activation='relu', padding='same')
encode_pool_layer_2 = MaxPooling2D((2, 2), padding='same')
encode_conv_layer_3 = Conv2D(4, (3, 3), activation='relu', padding='same')
encode_pool_layer_3 = MaxPooling2D((2, 2), padding='same')

encoded = encode_conv_layer_1(input_img)
encoded = encode_pool_layer_1(encoded)
encoded = encode_conv_layer_2(encoded)
encoded = encode_pool_layer_2(encoded)
encoded = encode_conv_layer_3(encoded)
encoded = encode_pool_layer_3(encoded)

# AutoEncoder 모델 구성 - Decoder 부분
decode_conv_layer_1 = Conv2D(4, (3, 3), activation='relu', padding='same')
decode_upsample_layer_1 = UpSampling2D((2, 2))
decode_conv_layer_2 = Conv2D(8, (3, 3), activation='relu', padding='same')
decode_upsample_layer_2 = UpSampling2D((2, 2))
decode_conv_layer_3 = Conv2D(16, (3, 3), activation='relu')
decode_upsample_layer_3 = UpSampling2D((2, 2))
decode_conv_layer_4 = Conv2D(1, (3, 3), activation='sigmoid', padding='same')

decoded = decode_conv_layer_1(encoded)   # Decoder는 Encoder의 출력을 입력으로 받습니다.
decoded = decode_upsample_layer_1(decoded)
decoded = decode_conv_layer_2(decoded)
decoded = decode_upsample_layer_2(decoded)
decoded = decode_conv_layer_3(decoded)
decoded = decode_upsample_layer_3(decoded)
decoded = decode_conv_layer_4(decoded)

autoencoder = Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 4)           292
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 4)          0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 4)           148
#
#  up_sampling2d (UpSampling2D  (None, 8, 8, 4)          0
#  )
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 8)           296
#
#  up_sampling2d_1 (UpSampling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_2 (UpSampling  (None, 28, 28, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 3,369
# Trainable params: 3,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 82s 344ms/step - loss: 0.6912 - val_loss: 0.6898
# Epoch 2/50
# 235/235 [==============================] - 80s 340ms/step - loss: 0.6883 - val_loss: 0.6866
# Epoch 3/50
# 235/235 [==============================] - 71s 301ms/step - loss: 0.6848 - val_loss: 0.6827
# Epoch 4/50
# 235/235 [==============================] - 71s 301ms/step - loss: 0
50
# 235/235 [==============================] - 72s 307ms/step - loss: 0.2893 - val_loss: 0.2889
# Epoch 49/50
# 235/235 [==============================] - 72s 305ms/step - loss: 0.2859 - val_loss: 0.2856
# Epoch 50/50
# 235/235 [==============================] - 72s 306ms/step - loss: 0.2829 - val_loss: 0.2827

# %%
x_test_10 = x_test[:10]       # 테스트 데이터셋에서 10개만 골라서
x_test_hat = autoencoder.predict(x_test_10)    # AutoEncoder 모델의 이미지 복원생성
x_test_imgs = x_test_10.reshape(-1, 28, 28)
x_test_hat_imgs = x_test_hat.reshape(-1, 28, 28)

plt.figure(figsize=(12,5))  # 이미지 사이즈 지정
for i in range(10):  
    # 원본이미지 출력
    plt.subplot(2, 10, i+1)
    plt.imshow(x_test_imgs[i])
    # 생성된 이미지 출력
    plt.subplot(2, 10, i+11)
    plt.imshow(x_test_hat_imgs[i])

# %%
from tensorflow.keras.layers import Conv2DTranspose

# Conv2DTranspose를 활용한  AutoEncoder 모델
# AutoEncoder 모델 구성 - Input 부분
input_shape = x_train.shape[1:]
input_img = Input(shape=input_shape)

# AutoEncoder 모델 구성 - Encoder 부분
encode_conv_layer_1 = Conv2D(16, (3, 3), activation='relu')
encode_pool_layer_1 = MaxPooling2D((2, 2))
encode_conv_layer_2 = Conv2D(8, (3, 3), activation='relu')
encode_pool_layer_2 = MaxPooling2D((2, 2))
encode_conv_layer_3 = Conv2D(4, (3, 3), activation='relu')

encoded = encode_conv_layer_1(input_img)
encoded = encode_pool_layer_1(encoded)
encoded = encode_conv_layer_2(encoded)
encoded = encode_pool_layer_2(encoded)
encoded = encode_conv_layer_3(encoded)

# AutoEncoder 모델 구성 - Decoder 부분  - 
decode_conv_layer_1 = Conv2DTranspose(4, (3, 3), activation='relu', padding='same')
decode_upsample_layer_1 = UpSampling2D((2, 2))
decode_conv_layer_2 = Conv2DTranspose(8, (3, 3), activation='relu', padding='same')
decode_upsample_layer_2 = UpSampling2D((2, 2))
decode_conv_layer_3 = Conv2DTranspose(16, (3, 3), activation='relu')
decode_upsample_layer_3 = UpSampling2D((2, 2))
decode_conv_layer_4 = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')

decoded = decode_conv_layer_1(encoded)   # Decoder는 Encoder의 출력을 입력으로 받습니다.
decoded = decode_upsample_layer_1(decoded)
decoded = decode_conv_layer_2(decoded)
decoded = decode_upsample_layer_2(decoded)
decoded = decode_conv_layer_3(decoded)
decoded = decode_upsample_layer_3(decoded)
decoded = decode_conv_layer_4(decoded)

# AutoEncoder 모델 정의
autoencoder = Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 8)         1160
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 8)          0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 3, 3, 4)           292
#
#  conv2d_transpose (Conv2DTra  (None, 3, 3, 4)          148
#  nspose)
#
#  up_sampling2d_3 (UpSampling  (None, 6, 6, 4)          0
#  2D)
#
#  conv2d_transpose_1 (Conv2DT  (None, 6, 6, 8)          296
#  ranspose)
#
#  up_sampling2d_4 (UpSampling  (None, 12, 12, 8)        0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 14, 14, 16)       1168
#  ranspose)
#
#  up_sampling2d_5 (UpSampling  (None, 28, 28, 16)       0
#  2D)
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        145
#  ranspose)
#
# =================================================================
# Total params: 3,369
# Trainable params: 3,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 8s 25ms/step - loss: 0.6939 - val_loss: 0.6932
# Epoch 2/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6924 - val_loss: 0.6915
# Epoch 3/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6906 - val_loss: 0.6897
# Epoch 4/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6886 - val_loss: 0.6876
# Epoch 5/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6863 - val_loss: 0.6850
# Epoch 6/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6835 - val_loss: 0.6820
# Epoch 7/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6800 - val_loss: 0.6780
# Epoch 8/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6755 - val_loss: 0.6728
# Epoch 9/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6692 - val_loss: 0.6654
# Epoch 10/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.6602 - val_loss: 0.6547
# Epoch 11/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.6471 - val_loss: 0.6391
# Epoch 12/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6284 - val_loss: 0.6181
# Epoch 13/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6060 - val_loss: 0.5967
# Epoch 14/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5868 - val_loss: 0.5819
# Epoch 15/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5747 - val_loss: 0.5728
# Epoch 16/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5661 - val_loss: 0.5651
# Epoch 17/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5584 - val_loss: 0.5576
# Epoch 18/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5508 - val_loss: 0.5499
# Epoch 19/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5431 - val_loss: 0.5422
# Epoch 20/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5353 - val_loss: 0.5342
# Epoch 21/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5272 - val_loss: 0.5260
# Epoch 22/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5187 - val_loss: 0.5172
# Epoch 23/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5098 - val_loss: 0.5078
# Epoch 24/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5001 - val_loss: 0.4977
# Epoch 25/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.4895 - val_loss: 0.4867
# Epoch 26/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.4782 - val_loss: 0.4748
# Epoch 27/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.4662 - val_loss: 0.4624
# Epoch 28/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.4536 - val_loss: 0.4494
# Epoch 29/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4405 - val_loss: 0.4361
# Epoch 30/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4274 - val_loss: 0.4230
# Epoch 31/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.4147 - val_loss: 0.4107
# Epoch 32/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.4030 - val_loss: 0.3993
# Epoch 33/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3920 - val_loss: 0.3885
# Epoch 34/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3817 - val_loss: 0.3783
# Epoch 35/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3719 - val_loss: 0.3688
# Epoch 36/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3629 - val_loss: 0.3600
# Epoch 37/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3548 - val_loss: 0.3522
# Epoch 38/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3475 - val_loss: 0.3453
# Epoch 39/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3414 - val_loss: 0.3395
# Epoch 40/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3361 - val_loss: 0.3346
# Epoch 41/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3317 - val_loss: 0.3305
# Epoch 42/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3280 - val_loss: 0.3270
# Epoch 43/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3249 - val_loss: 0.3240
# Epoch 44/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3222 - val_loss: 0.3214
# Epoch 45/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3197 - val_loss: 0.3191
# Epoch 46/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3176 - val_loss: 0.3170
# Epoch 47/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3156 - val_loss: 0.3150
# Epoch 48/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3137 - val_loss: 0.3132
# Epoch 49/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3119 - val_loss: 0.3114
# Epoch 50/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3103 - val_loss: 0.3098

# %%
x_test_10 = x_test[:10]       # 테스트 데이터셋에서 10개만 골라서
x_test_hat = autoencoder.predict(x_test_10)    # AutoEncoder 모델의 이미지 복원생성
x_test_imgs = x_test_10.reshape(-1, 28, 28)
x_test_hat_imgs = x_test_hat.reshape(-1, 28, 28)

plt.figure(figsize=(12,5))  # 이미지 사이즈 지정
for i in range(10):  
    # 원본이미지 출력
    plt.subplot(2, 10, i+1)
    plt.imshow(x_test_imgs[i])
    # 생성된 이미지 출력
    plt.subplot(2, 10, i+11)
    plt.imshow(x_test_hat_imgs[i])
